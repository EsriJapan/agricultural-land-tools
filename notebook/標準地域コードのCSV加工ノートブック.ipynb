# %% [markdown]
# ## 標準地域コード - 全国CSV から city_code.csv を作成するサンプルノートブック
#
# [統計に用いる標準地域コード](https://www.soumu.go.jp/toukei_toukatsu/index/seido/9-5.htm) で入手可能な全国CSV をもとに、
# [Agricultural Land Pin Tools](https://github.com/EsriJapan/agricultural-land-tools) で利用する **city_code.csv** に加工するサンプルノートブックです。
#
# 参考：統計に用いる標準地域コード
# https://www.soumu.go.jp/toukei_toukatsu/index/seido/9-5.htm

# %% [markdown]
# ### 全国CSVを読込み、埼玉県の市区町村を例に抽出します

# %%
import os
import pandas as pd
#フォルダー（それぞれ変更のこと）
folder = r"C:\TEMP\標準メッシュコード"
#全国CSVのファイル名（取得した時点の状況により変更のこと）
in_csv_file = os.path.join(folder, "000323625.csv")
#city_code.csv（ツールで指定しているファイル名なので基本的に固定）
out_csv_file = os.path.join(folder, "city_code.csv")

# %%
#全ての列をobjectとして読み込み
df = pd.read_csv(in_csv_file, encoding='cp932', dtype = 'object')

# %%
#ken-codeとsityouson-name3がNaNでないものを抽出（ken-code:11 は埼玉の例なので、状況により変更のこと）
df_city = df[ (df['ken-code'] == '11') & (df['sityouson-name3'].isnull() == False) ]
df_city
# Out:
#     ken-code sityouson-code tiiki-code ken-name sityouson-name1  \
# 631       11            101      11101      埼玉県           さいたま市
# 632       11            102      11102      埼玉県           さいたま市
# 633       11            103      11103      埼玉県           さいたま市
# 634       11            104      11104      埼玉県           さいたま市
# 635       11            105      11105      埼玉県           さいたま市
# ..       ...            ...        ...      ...             ...
# 703       11            385      11385      埼玉県             児玉郡
# 705       11            408      11408      埼玉県             大里郡
# 707       11            442      11442      埼玉県            南埼玉郡
# 709       11            464      11464      埼玉県            北葛飾郡
# 710       11            465      11465      埼玉県            北葛飾郡
#
#     sityouson-name2 sityouson-name3 yomigana
# 631             NaN              西区      にしく
# 632             NaN              北区      きたく
# 633             NaN             大宮区    おおみやく
# 634             NaN             見沼区     みぬまく
# 635             NaN             中央区   ちゅうおうく
# ..              ...             ...      ...
# 703             NaN             上里町   かみさとまち
# 705             NaN             寄居町    よりいまち
# 707             NaN             宮代町   みやしろまち
# 709             NaN             杉戸町    すぎとまち
# 710             NaN             松伏町   まつぶしまち
#
# [72 rows x 8 columns]

# %% [markdown]
# ###  city_code.csvでの出力列 code, name になるように加工します

# %%
# 出力用にDataFrame をコピー
out_df = df_city.copy()
# sityouson-name1 と sityouson-name3 から name 列を作成
out_df['name'] = out_df['sityouson-name1'].fillna('') + out_df['sityouson-name3'].fillna('')

# %%
# tiiki-code を code に変更
out_df.rename(columns={'tiiki-code': 'code'}, inplace=True)
out_df
# Out:
#     ken-code sityouson-code   code ken-name sityouson-name1 sityouson-name2  \
# 631       11            101  11101      埼玉県           さいたま市             NaN
# 632       11            102  11102      埼玉県           さいたま市             NaN
# 633       11            103  11103      埼玉県           さいたま市             NaN
# 634       11            104  11104      埼玉県           さいたま市             NaN
# 635       11            105  11105      埼玉県           さいたま市             NaN
# ..       ...            ...    ...      ...             ...             ...
# 703       11            385  11385      埼玉県             児玉郡             NaN
# 705       11            408  11408      埼玉県             大里郡             NaN
# 707       11            442  11442      埼玉県            南埼玉郡             NaN
# 709       11            464  11464      埼玉県            北葛飾郡             NaN
# 710       11            465  11465      埼玉県            北葛飾郡             NaN
#
#     sityouson-name3 yomigana      name
# 631              西区      にしく   さいたま市西区
# 632              北区      きたく   さいたま市北区
# 633             大宮区    おおみやく  さいたま市大宮区
# 634             見沼区     みぬまく  さいたま市見沼区
# 635             中央区   ちゅうおうく  さいたま市中央区
# ..              ...      ...       ...
# 703             上里町   かみさとまち    児玉郡上里町
# 705             寄居町    よりいまち    大里郡寄居町
# 707             宮代町   みやしろまち   南埼玉郡宮代町
# 709             杉戸町    すぎとまち   北葛飾郡杉戸町
# 710             松伏町   まつぶしまち   北葛飾郡松伏町
#
# [72 rows x 9 columns]

# %% [markdown]
# ### city_code.csv へ保存します

# %%
out_df.to_csv(out_csv_file, columns=['code', 'name'] ,index=False)
